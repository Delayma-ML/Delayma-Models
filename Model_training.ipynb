# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/Vartika/Documents/GitHub/Delayma-Models/Datasets/df_1_10.csv')
df.head()
# Out:
#    MONTH  DAY_OF_MONTH  DAY_OF_WEEK  OP_UNIQUE_CARRIER  DEST  DEP_DELAY  \
# 0     11             1            5                  3    28          0
# 1     11             1            5                  3    20          1
# 2     11             1            5                  3    30          0
# 3     11             1            5                  4     1          0
# 4     11             1            5                  1    28          0
#
#    CRS_ELAPSED_TIME  DISTANCE  CRS_DEP_M  DEP_TIME_M  ...  Drizzle  Snow  \
# 0               371      2475        340         333  ...        0     0
# 1               181      1069        301         341  ...        0     0
# 2               168       944        345         343  ...        0     0
# 3               139       760        360         356  ...        0     0
# 4               373      2475        360         359  ...        0     0
#
#    Wintry Mix  Freezing Rain  MONTH_sin  MONTH_cos  DAY_OF_MONTH_sin  \
# ...

# %%
# draw heatmap between rain drizzle windy mix and delay
# print correlation matrix
corr = df.corr()
corr
# Out:
#                       MONTH  DAY_OF_MONTH  DAY_OF_WEEK  OP_UNIQUE_CARRIER  \
# MONTH              1.000000     -0.017878     0.029797           0.012424
# DAY_OF_MONTH      -0.017878      1.000000    -0.030224           0.010621
# DAY_OF_WEEK        0.029797     -0.030224     1.000000          -0.000299
# OP_UNIQUE_CARRIER  0.012424      0.010621    -0.000299           1.000000
# DEST              -0.008480     -0.005655    -0.002954          -0.016241
# DEP_DELAY          0.080222     -0.028849     0.015557           0.005474
# CRS_ELAPSED_TIME  -0.011192     -0.010029    -0.008534          -0.084666
# DISTANCE           0.004030     -0.016425    -0.006865          -0.072437
# CRS_DEP_M         -0.004434      0.006790     0.001589           0.020919
# DEP_TIME_M        -0.003564      0.006396     0.004835           0.020405
# CRS_ARR_M         -0.022690      0.013533    -0.005619           0.079333
# Temperature        0.142239     -0.132947     0.009275           0.025342
# ...

# %%
# train this model on 80% of the data and test on 20%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(df, df['DEP_DELAY'], test_size=0.4, random_state=0)

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# train the model
random_forest = RandomForestClassifier(n_estimators=6, max_depth=5, random_state=1)
random_forest.fit(xtrain, ytrain)
y_pred = random_forest.predict(xtest)
print(accuracy_score(ytest, y_pred))
# print confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(ytest, y_pred)
print(confusion_matrix(ytest, y_pred))
# Out:
# 0.9904046725073008
# [[4170    0]
#  [  46  578]]

# %%
df_2 = pd.read_csv('C:/Users/Vartika/Documents/GitHub/Delayma-Models/Datasets/df_1_25.csv')
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(df_2, df_2['DEP_DELAY'], test_size=0.4, random_state=0)
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# train the model
random_forest = RandomForestClassifier(n_estimators=6, max_depth=5, random_state=1)
random_forest.fit(xtrain, ytrain)
y_pred = random_forest.predict(xtest)
print(accuracy_score(ytest, y_pred))
# print confusion matrix
from sklearn.metrics import confusion_matrix

confusion_matrix(ytest, y_pred)
print(confusion_matrix(ytest, y_pred))
# Out:
# 0.9794053131854741
# [[7123    0]
#  [ 169  914]]

# %%
df_3 = pd.read_csv('C:/Users/Vartika/Documents/GitHub/Delayma-Models/Datasets/df_1_3.csv')
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(df_2, df_2['DEP_DELAY'], test_size=0.4, random_state=0)
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# train the model
random_forest = RandomForestClassifier(n_estimators=6, max_depth=5, random_state=1)
random_forest.fit(xtrain, ytrain)
y_pred = random_forest.predict(xtest)
print(accuracy_score(ytest, y_pred))
# print confusion matrix
from sklearn.metrics import confusion_matrix

confusion_matrix(ytest, y_pred)
print(confusion_matrix(ytest, y_pred))
# Out:
# 0.9794053131854741
# [[7123    0]
#  [ 169  914]]

# %%
df_4 = pd.read_csv('C:/Users/Vartika/Documents/GitHub/Delayma-Models/Datasets/df_preprocessed.csv')
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(df_4, df_4['DEP_DELAY'], test_size=0.4, random_state=0)
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# train the model
random_forest = RandomForestClassifier(n_estimators=6, max_depth=3, random_state=1)
random_forest.fit(xtrain, ytrain)
y_pred = random_forest.predict(xtest)
print(accuracy_score(ytest, y_pred))
# print confusion matrix
from sklearn.metrics import confusion_matrix

confusion_matrix(ytest, y_pred)
print(confusion_matrix(ytest, y_pred))
# Out:
# 0.8893129770992366
# [[10011     0]
#  [ 1276   241]]

# %% [markdown]
# ## TRYING REGRESSION

# %%
df_regression = pd.read_csv('C:/Users/Vartika/Documents/GitHub/Delayma-Models/Datasets/m1_final_regression_dataset.csv')

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

xtrain, xtest, ytrain, ytest = train_test_split(df_regression, df_regression['DEP_DELAY'], test_size=0.4, random_state=0)
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestRegressor

# train the model
random_forest = RandomForestRegressor(n_estimators=10, max_depth=5, random_state=1)
random_forest.fit(xtrain, ytrain)
y_pred = random_forest.predict(xtest)
ytest = ytest.to_numpy()
# for i in range(len(y_pred)):
    # print(y_pred[i],ytest[i])
# find mean squared error
mean_squared_error = mean_squared_error(y_pred,ytest)
print(mean_squared_error)
# Out:
# 11.521809734288023
